# %%
import pandas as pd

# %%
import numpy as np

# %%
import seaborn as sns

# %%
df = pd.read_csv("Downloads/Dataset/iris.csv")

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.distplot(df["sepal_length"], kde = False)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17732\2492894334.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["sepal_length"], kde = False)
# <Axes: xlabel='sepal_length'>

# %%
sns.distplot(df["sepal_width"], rug = True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17732\3257791575.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["sepal_width"], rug = True)
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.hist(df["sepal_length"])
# Out:
# (array([ 9., 23., 14., 27., 16., 26., 18.,  6.,  5.,  6.]),
#  array([4.3 , 4.66, 5.02, 5.38, 5.74, 6.1 , 6.46, 6.82, 7.18, 7.54, 7.9 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df["petal_width"], bins = 40)
# Out:
# (array([ 6., 28.,  0.,  7.,  0.,  7.,  1.,  0.,  1.,  0.,  0.,  0.,  0.,
#          0.,  0.,  7.,  3.,  0.,  5.,  0., 13.,  8.,  0., 12.,  0.,  4.,
#          2.,  0., 12.,  0.,  5.,  6.,  0.,  6.,  0.,  3.,  8.,  0.,  3.,
#          3.]),
#  array([0.1 , 0.16, 0.22, 0.28, 0.34, 0.4 , 0.46, 0.52, 0.58, 0.64, 0.7 ,
#         0.76, 0.82, 0.88, 0.94, 1.  , 1.06, 1.12, 1.18, 1.24, 1.3 , 1.36,
#         1.42, 1.48, 1.54, 1.6 , 1.66, 1.72, 1.78, 1.84, 1.9 , 1.96, 2.02,
#         2.08, 2.14, 2.2 , 2.26, 2.32, 2.38, 2.44, 2.5 ]),
#  <BarContainer object of 40 artists>)

# %%
sns.boxplot(df["petal_length"])
# Out:
# <Axes: >

# %%
sns.boxplot(df["petal_width"])
# Out:
# <Axes: >

# %%
sns.boxplot(x=df["sepal_length"], y = df["petal_length"], hue = df["petal_width"])
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
sns.boxplot(data = df, x = df["petal_length"], y = df["species"])
# Out:
# <Axes: xlabel='petal_length', ylabel='species'>

# %%
sns.boxplot(data = df, x = df["species"], y = df["sepal_width"])
# Out:
# <Axes: xlabel='species', ylabel='sepal_width'>

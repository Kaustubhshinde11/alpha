# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv("StudentsPerformance.csv")

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
df.isnull()
# Out:
#      gender  race/ethnicity  parental level of education  lunch  \
# 0     False           False                        False  False
# 1     False           False                        False  False
# 2     False           False                        False  False
# 3     False           False                        False  False
# 4     False           False                        False  False
# ..      ...             ...                          ...    ...
# 995   False           False                        False  False
# 996   False           False                        False  False
# 997   False           False                        False  False
# 998   False           False                        False  False
# 999   False           False                        False  False
#
#      test preparation course  math score  reading score  writing score
# 0                      False       False          False          False
# ...

# %%
df["math score"] = df["math score"].interpolate()
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.isnull().sum(0)
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
df["writing score"] = df["writing score"].fillna(method='bfill')
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
df.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
df ["math score"] = df ["math score"].astype('float64')
df ["writing score"] = df ["writing score"].astype('int64')
df ["reading score"] = df ["reading score"].astype('float64')
df.dtypes
# Out:
# gender                          object
# race/ethnicity                  object
# parental level of education     object
# lunch                           object
# test preparation course         object
# math score                     float64
# reading score                  float64
# writing score                    int64
# dtype: object

# %%
columns = ["math score", "writing score", "reading score"]
df.boxplot(columns)
# Out:
# <Axes: >

# %%
np.where(df["math score"] < 60)
# Out:
# (array([  3,   7,   9,  10,  11,  14,  17,  18,  19,  22,  32,  33,  37,
#          39,  40,  41,  42,  43,  44,  46,  48,  50,  52,  55,  57,  58,
#          59,  61,  64,  66,  69,  70,  72,  74,  75,  76,  80,  81,  82,
#          84,  88,  91,  93,  98, 105, 108, 112, 113, 118, 119, 129, 131,
#         135, 136, 138, 141, 142, 143, 145, 152, 153, 162, 163, 166, 167,
#         174, 176, 178, 181, 182, 184, 188, 196, 197, 198, 203, 204, 209,
#         211, 212, 217, 220, 222, 224, 225, 227, 231, 238, 242, 243, 247,
#         250, 254, 262, 265, 271, 272, 277, 280, 281, 284, 296, 298, 301,
#         307, 308, 309, 314, 319, 323, 324, 327, 329, 331, 337, 338, 339,
#         340, 350, 353, 354, 357, 358, 360, 362, 363, 364, 365, 368, 371,
#         374, 375, 383, 384, 387, 393, 395, 396, 400, 401, 402, 404, 408,
#         414, 419, 421, 422, 423, 424, 433, 435, 442, 448, 454, 455, 457,
#         460, 461, 466, 473, 478, 481, 483, 484, 494, 496, 497, 504, 507,
# ...

# %%
np.where(df["math score"] > 90)
# Out:
# (array([ 34, 104, 114, 121, 149, 165, 171, 179, 233, 263, 286, 306, 451,
#         458, 469, 501, 503, 521, 539, 546, 562, 566, 571, 594, 612, 618,
#         623, 625, 685, 689, 710, 712, 717, 719, 736, 779, 784, 815, 846,
#         855, 864, 886, 903, 916, 919, 934, 950, 957, 962, 979]),)

# %%
np.where(df["reading score"]>85)
# Out:
# (array([  1,   2,   6,  16,  34,  38,  89,  94, 102, 104, 106, 110, 114,
#         120, 121, 122, 125, 149, 155, 158, 161, 164, 165, 171, 172, 175,
#         179, 189, 214, 216, 229, 232, 233, 263, 268, 276, 278, 287, 299,
#         306, 321, 325, 334, 347, 359, 373, 376, 377, 380, 381, 397, 403,
#         420, 439, 451, 456, 458, 463, 465, 468, 472, 474, 493, 501, 503,
#         509, 514, 515, 516, 521, 533, 539, 543, 546, 551, 562, 566, 571,
#         577, 580, 594, 604, 612, 614, 623, 625, 633, 637, 641, 652, 659,
#         685, 689, 695, 708, 712, 715, 717, 722, 728, 732, 753, 755, 781,
#         802, 815, 819, 820, 821, 823, 828, 831, 855, 861, 864, 873, 886,
#         891, 903, 916, 919, 934, 941, 956, 957, 962, 970, 979, 983, 989,
#         995, 999]),)

# %%
np.where(df["reading score"]>99)
# Out:
# (array([106, 114, 149, 165, 179, 381, 458, 546, 566, 594, 712, 886, 903,
#         916, 957, 962, 970]),)

# %%
np.where(df["writing score"]<50)
# Out:
# (array([  3,   7,  11,  17,  18,  33,  50,  52,  55,  57,  59,  61,  66,
#          72,  74,  75,  76,  81,  84,  91, 103, 111, 112, 131, 135, 136,
#         143, 145, 153, 163, 182, 184, 188, 204, 211, 217, 231, 243, 250,
#         265, 271, 280, 281, 284, 296, 307, 324, 327, 331, 337, 338, 363,
#         375, 383, 384, 395, 401, 424, 448, 453, 455, 457, 461, 466, 483,
#         511, 524, 527, 528, 554, 555, 564, 565, 568, 596, 597, 601, 616,
#         627, 628, 683, 688, 706, 723, 724, 729, 731, 733, 744, 770, 777,
#         785, 787, 807, 810, 811, 834, 840, 842, 858, 862, 867, 870, 883,
#         889, 895, 896, 902, 910, 921, 928, 978, 980, 988]),)

# %%
np.where(df["writing score"]<35)
# Out:
# (array([ 17,  59,  61,  76,  84, 145, 211, 327, 338, 363, 424, 555, 596,
#         601, 787, 896, 980]),)

# %%
df[(df["reading score"] < 75) & (df["reading score"] > 30)]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 7      male        group B                some college  free/reduced
# 8      male        group D                 high school  free/reduced
# 9    female        group B                 high school  free/reduced
# ..      ...            ...                         ...           ...
# 988  female        group A            some high school  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 994    male        group A                 high school      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df[(df["writing score"] < 90) & (df["writing score"] > 50)]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# 8      male        group D                 high school  free/reduced
# ..      ...            ...                         ...           ...
# 994    male        group A                 high school      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
 new_df1 = df[
     ((df["math score"] >= 60) & (df["math score"] <=80 )) &
     ((df["reading score"] >=75) & (df["reading score"] <=95)) &
      ((df["writing score"] >=60) & (df["writing score"] <=80))]

# %%
new_df1
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# 12   female        group B                 high school      standard
# 15   female        group C            some high school      standard
# 21   female        group B                some college  free/reduced
# ..      ...            ...                         ...           ...
# 968  female        group E          associate's degree      standard
# 969  female        group B           bachelor's degree      standard
# 975  female        group C                some college      standard
# 991  female        group B            some high school      standard
# 998  female        group D                some college      standard
#
#     test preparation course  math score  reading score  writing score
# ...
